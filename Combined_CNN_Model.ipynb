# %%
from keras.models import Model
from keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Dropout
from keras.layers.core import Lambda
from keras.layers.core import Dense
from keras.layers import Flatten
from keras.layers import Input
import tensorflow as tf
import keras
import tensorflow
from keras import layers
import numpy as np
import tensorflow as tf
import tensorflow
from tensorflow import keras
from keras import layers
from tensorflow.keras.utils import plot_model
import pandas as pd
import matplotlib.pyplot as plt
from keras import regularizers, optimizers
from keras.layers import Dense, Dropout, Input
from keras.models import Sequential, load_model
from keras.callbacks import ModelCheckpoint
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError,MeanSquaredError,MeanAbsoluteError
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
import os

# %%
"""
input shape  = (12,10,126)
output shape = (12,1)
"""
# Out:
# '\ninput shape  = (12,10,126)\noutput shape = (12,1)\n'

# %%
no_loudness_levels = 12

# %%
inputs = Input(shape = (no_loudness_levels,10,126))
x = Conv2D(32, (3, 3), padding="same")(inputs)
x = Activation("relu")(x)
x = BatchNormalization(axis=-1)(x)
x = MaxPooling2D(pool_size=(3,3))(x)
x = Dropout(0.25)(x)
x = Conv2D(32, (3, 3), padding="same")(x)
x = Activation("relu")(x)
x = BatchNormalization(axis=-1)(x)
x = MaxPooling2D(pool_size=(2, 2),padding = 'same')(x)
x = Dropout(0.25)(x)
x = Conv2D(32, (3, 3), padding="same")(x)
x = Activation("relu")(x)
x = BatchNormalization(axis=-1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Dropout(0.25)(x)
x = Flatten()(x)
x = Dense(128)(x)
x = Activation("relu")(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(no_loudness_levels)(x)
x = Activation("linear", name="final-output")(x)

# %%
model = keras.Model(inputs = inputs, outputs = x,name = "CNN_combined")

# %%
model.summary()
# Out:
# Model: "CNN_combined"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 12, 10, 126)]     0
#
#  conv2d (Conv2D)             (None, 12, 10, 32)        36320
#
#  activation (Activation)     (None, 12, 10, 32)        0
#
#  batch_normalization (BatchN  (None, 12, 10, 32)       128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 4, 3, 32)         0
#  )
#
#  dropout (Dropout)           (None, 4, 3, 32)          0
#
#  conv2d_1 (Conv2D)           (None, 4, 3, 32)          9248
#
#  activation_1 (Activation)   (None, 4, 3, 32)          0
#
#  batch_normalization_1 (Batc  (None, 4, 3, 32)         128
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 2, 2, 32)          0
#
#  conv2d_2 (Conv2D)           (None, 2, 2, 32)          9248
#
#  activation_2 (Activation)   (None, 2, 2, 32)          0
#
#  batch_normalization_2 (Batc  (None, 2, 2, 32)         128
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 32)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 1, 1, 32)          0
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense (Dense)               (None, 128)               4224
#
#  activation_3 (Activation)   (None, 128)               0
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 12)                1548
#
#  final-output (Activation)   (None, 12)                0
#
# =================================================================
# Total params: 61,484
# Trainable params: 61,036
# Non-trainable params: 448
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(
    model,
    show_shapes=False,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=True,
    dpi=70,
    layer_range=None,
    show_layer_activations=False,
)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
x = np.load('ewt_X_cnn.npy')
y = np.load('ewt_Y_cnn.npy')

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size = 0.85)

# %%
print(x.shape)
print(y.shape)
# Out:
# (9000, 12, 10, 126)
# (9000, 12)

# %%
optimizer = keras.optimizers.Adam(learning_rate = 1e-4)
model.compile(loss='mean_squared_error', optimizer = optimizer,metrics = ['MeanAbsoluteError','MeanSquaredError']) # Try SGD, adam, adagrad and compare!!!
file = 'best_combined_model.h5'
es = EarlyStopping(monitor='val_loss', mode='min', verbose=5, patience=25)
checkpoint = ModelCheckpoint(filepath=file, 
                             monitor='val_loss',
                             verbose=1, 
                             save_best_only=True,
                             mode='min')
callbacks = [checkpoint,es]

# %%
history = model.fit(x_train,y_train, epochs=700, batch_size=16, verbose=2,validation_data = (x_test,y_test), callbacks = callbacks)
# Out:
# Epoch 1/700
#
# Epoch 1: val_loss improved from inf to 0.84160, saving model to best_combined_model.h5
# 479/479 - 14s - loss: 3.4097 - mean_absolute_error: 1.3926 - mean_squared_error: 3.4097 - val_loss: 0.8416 - val_mean_absolute_error: 0.7953 - val_mean_squared_error: 0.8416 - 14s/epoch - 28ms/step
# Epoch 2/700
#
# Epoch 2: val_loss improved from 0.84160 to 0.60189, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 2.4293 - mean_absolute_error: 1.1877 - mean_squared_error: 2.4293 - val_loss: 0.6019 - val_mean_absolute_error: 0.6641 - val_mean_squared_error: 0.6019 - 10s/epoch - 20ms/step
# Epoch 3/700
#
# Epoch 3: val_loss improved from 0.60189 to 0.42996, saving model to best_combined_model.h5
# 479/479 - 11s - loss: 1.8730 - mean_absolute_error: 1.0416 - mean_squared_error: 1.8730 - val_loss: 0.4300 - val_mean_absolute_error: 0.5571 - val_mean_squared_error: 0.4300 - 11s/epoch - 22ms/step
# Epoch 4/700
#
# Epoch 4: val_loss improved from 0.42996 to 0.30471, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 1.4260 - mean_absolute_error: 0.9059 - mean_squared_error: 1.4260 - val_loss: 0.3047 - val_mean_absolute_error: 0.4698 - val_mean_squared_error: 0.3047 - 10s/epoch - 21ms/step
# Epoch 5/700
#
# Epoch 5: val_loss improved from 0.30471 to 0.20195, saving model to best_combined_model.h5
# 479/479 - 12s - loss: 1.1130 - mean_absolute_error: 0.7955 - mean_squared_error: 1.1130 - val_loss: 0.2020 - val_mean_absolute_error: 0.3780 - val_mean_squared_error: 0.2020 - 12s/epoch - 24ms/step
# Epoch 6/700
#
# Epoch 6: val_loss improved from 0.20195 to 0.14010, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.8715 - mean_absolute_error: 0.6989 - mean_squared_error: 0.8715 - val_loss: 0.1401 - val_mean_absolute_error: 0.3191 - val_mean_squared_error: 0.1401 - 10s/epoch - 22ms/step
# Epoch 7/700
#
# Epoch 7: val_loss improved from 0.14010 to 0.11054, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.6922 - mean_absolute_error: 0.6237 - mean_squared_error: 0.6922 - val_loss: 0.1105 - val_mean_absolute_error: 0.2792 - val_mean_squared_error: 0.1105 - 10s/epoch - 21ms/step
# Epoch 8/700
#
# Epoch 8: val_loss improved from 0.11054 to 0.09871, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.5683 - mean_absolute_error: 0.5661 - mean_squared_error: 0.5683 - val_loss: 0.0987 - val_mean_absolute_error: 0.2604 - val_mean_squared_error: 0.0987 - 10s/epoch - 21ms/step
# Epoch 9/700
#
# Epoch 9: val_loss improved from 0.09871 to 0.09169, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.4634 - mean_absolute_error: 0.5169 - mean_squared_error: 0.4634 - val_loss: 0.0917 - val_mean_absolute_error: 0.2543 - val_mean_squared_error: 0.0917 - 10s/epoch - 21ms/step
# Epoch 10/700
#
# Epoch 10: val_loss improved from 0.09169 to 0.08692, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.3895 - mean_absolute_error: 0.4774 - mean_squared_error: 0.3895 - val_loss: 0.0869 - val_mean_absolute_error: 0.2410 - val_mean_squared_error: 0.0869 - 10s/epoch - 21ms/step
# Epoch 11/700
#
# Epoch 11: val_loss improved from 0.08692 to 0.08524, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.3268 - mean_absolute_error: 0.4395 - mean_squared_error: 0.3268 - val_loss: 0.0852 - val_mean_absolute_error: 0.2397 - val_mean_squared_error: 0.0852 - 10s/epoch - 21ms/step
# Epoch 12/700
#
# Epoch 12: val_loss improved from 0.08524 to 0.08354, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.2700 - mean_absolute_error: 0.4060 - mean_squared_error: 0.2700 - val_loss: 0.0835 - val_mean_absolute_error: 0.2365 - val_mean_squared_error: 0.0835 - 10s/epoch - 21ms/step
# Epoch 13/700
#
# Epoch 13: val_loss did not improve from 0.08354
# 479/479 - 10s - loss: 0.2283 - mean_absolute_error: 0.3787 - mean_squared_error: 0.2283 - val_loss: 0.0839 - val_mean_absolute_error: 0.2363 - val_mean_squared_error: 0.0839 - 10s/epoch - 20ms/step
# Epoch 14/700
#
# Epoch 14: val_loss improved from 0.08354 to 0.08244, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.1919 - mean_absolute_error: 0.3507 - mean_squared_error: 0.1919 - val_loss: 0.0824 - val_mean_absolute_error: 0.2335 - val_mean_squared_error: 0.0824 - 10s/epoch - 21ms/step
# Epoch 15/700
#
# Epoch 15: val_loss improved from 0.08244 to 0.08108, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.1676 - mean_absolute_error: 0.3309 - mean_squared_error: 0.1676 - val_loss: 0.0811 - val_mean_absolute_error: 0.2304 - val_mean_squared_error: 0.0811 - 10s/epoch - 21ms/step
# Epoch 16/700
#
# Epoch 16: val_loss improved from 0.08108 to 0.08099, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.1480 - mean_absolute_error: 0.3132 - mean_squared_error: 0.1480 - val_loss: 0.0810 - val_mean_absolute_error: 0.2315 - val_mean_squared_error: 0.0810 - 10s/epoch - 21ms/step
# Epoch 17/700
#
# Epoch 17: val_loss improved from 0.08099 to 0.08035, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.1322 - mean_absolute_error: 0.2984 - mean_squared_error: 0.1322 - val_loss: 0.0804 - val_mean_absolute_error: 0.2299 - val_mean_squared_error: 0.0804 - 10s/epoch - 21ms/step
# Epoch 18/700
#
# Epoch 18: val_loss improved from 0.08035 to 0.08035, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.1202 - mean_absolute_error: 0.2852 - mean_squared_error: 0.1202 - val_loss: 0.0803 - val_mean_absolute_error: 0.2303 - val_mean_squared_error: 0.0803 - 10s/epoch - 20ms/step
# Epoch 19/700
#
# Epoch 19: val_loss improved from 0.08035 to 0.07963, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.1107 - mean_absolute_error: 0.2737 - mean_squared_error: 0.1107 - val_loss: 0.0796 - val_mean_absolute_error: 0.2288 - val_mean_squared_error: 0.0796 - 10s/epoch - 20ms/step
# Epoch 20/700
#
# Epoch 20: val_loss improved from 0.07963 to 0.07928, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.1050 - mean_absolute_error: 0.2666 - mean_squared_error: 0.1050 - val_loss: 0.0793 - val_mean_absolute_error: 0.2269 - val_mean_squared_error: 0.0793 - 10s/epoch - 21ms/step
# Epoch 21/700
#
# Epoch 21: val_loss improved from 0.07928 to 0.07895, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.1000 - mean_absolute_error: 0.2601 - mean_squared_error: 0.1000 - val_loss: 0.0789 - val_mean_absolute_error: 0.2251 - val_mean_squared_error: 0.0789 - 10s/epoch - 20ms/step
# Epoch 22/700
#
# Epoch 22: val_loss did not improve from 0.07895
# 479/479 - 10s - loss: 0.0969 - mean_absolute_error: 0.2557 - mean_squared_error: 0.0969 - val_loss: 0.0797 - val_mean_absolute_error: 0.2295 - val_mean_squared_error: 0.0797 - 10s/epoch - 20ms/step
# Epoch 23/700
#
# Epoch 23: val_loss improved from 0.07895 to 0.07874, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.0950 - mean_absolute_error: 0.2526 - mean_squared_error: 0.0950 - val_loss: 0.0787 - val_mean_absolute_error: 0.2252 - val_mean_squared_error: 0.0787 - 10s/epoch - 20ms/step
# Epoch 24/700
#
# Epoch 24: val_loss improved from 0.07874 to 0.07871, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.0922 - mean_absolute_error: 0.2479 - mean_squared_error: 0.0922 - val_loss: 0.0787 - val_mean_absolute_error: 0.2264 - val_mean_squared_error: 0.0787 - 10s/epoch - 20ms/step
# Epoch 25/700
#
# Epoch 25: val_loss did not improve from 0.07871
# 479/479 - 10s - loss: 0.0915 - mean_absolute_error: 0.2469 - mean_squared_error: 0.0915 - val_loss: 0.0790 - val_mean_absolute_error: 0.2266 - val_mean_squared_error: 0.0790 - 10s/epoch - 20ms/step
# Epoch 26/700
#
# Epoch 26: val_loss improved from 0.07871 to 0.07816, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.0901 - mean_absolute_error: 0.2444 - mean_squared_error: 0.0901 - val_loss: 0.0782 - val_mean_absolute_error: 0.2243 - val_mean_squared_error: 0.0782 - 10s/epoch - 21ms/step
# Epoch 27/700
#
# Epoch 27: val_loss improved from 0.07816 to 0.07815, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.0892 - mean_absolute_error: 0.2422 - mean_squared_error: 0.0892 - val_loss: 0.0781 - val_mean_absolute_error: 0.2233 - val_mean_squared_error: 0.0781 - 10s/epoch - 21ms/step
# Epoch 28/700
#
# Epoch 28: val_loss improved from 0.07815 to 0.07804, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.0882 - mean_absolute_error: 0.2411 - mean_squared_error: 0.0882 - val_loss: 0.0780 - val_mean_absolute_error: 0.2238 - val_mean_squared_error: 0.0780 - 10s/epoch - 21ms/step
# Epoch 29/700
#
# Epoch 29: val_loss improved from 0.07804 to 0.07744, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.0871 - mean_absolute_error: 0.2386 - mean_squared_error: 0.0871 - val_loss: 0.0774 - val_mean_absolute_error: 0.2199 - val_mean_squared_error: 0.0774 - 10s/epoch - 21ms/step
# Epoch 30/700
#
# Epoch 30: val_loss did not improve from 0.07744
# 479/479 - 10s - loss: 0.0877 - mean_absolute_error: 0.2402 - mean_squared_error: 0.0877 - val_loss: 0.0775 - val_mean_absolute_error: 0.2202 - val_mean_squared_error: 0.0775 - 10s/epoch - 20ms/step
# Epoch 31/700
#
# Epoch 31: val_loss did not improve from 0.07744
# 479/479 - 10s - loss: 0.0867 - mean_absolute_error: 0.2385 - mean_squared_error: 0.0867 - val_loss: 0.0780 - val_mean_absolute_error: 0.2249 - val_mean_squared_error: 0.0780 - 10s/epoch - 20ms/step
# Epoch 32/700
#
# Epoch 32: val_loss improved from 0.07744 to 0.07706, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.0859 - mean_absolute_error: 0.2366 - mean_squared_error: 0.0859 - val_loss: 0.0771 - val_mean_absolute_error: 0.2176 - val_mean_squared_error: 0.0771 - 10s/epoch - 21ms/step
# Epoch 33/700
#
# Epoch 33: val_loss did not improve from 0.07706
# 479/479 - 10s - loss: 0.0853 - mean_absolute_error: 0.2353 - mean_squared_error: 0.0853 - val_loss: 0.0776 - val_mean_absolute_error: 0.2213 - val_mean_squared_error: 0.0776 - 10s/epoch - 20ms/step
# Epoch 34/700
#
# Epoch 34: val_loss improved from 0.07706 to 0.07670, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.0843 - mean_absolute_error: 0.2333 - mean_squared_error: 0.0843 - val_loss: 0.0767 - val_mean_absolute_error: 0.2164 - val_mean_squared_error: 0.0767 - 10s/epoch - 21ms/step
# Epoch 35/700
#
# Epoch 35: val_loss did not improve from 0.07670
# 479/479 - 10s - loss: 0.0837 - mean_absolute_error: 0.2317 - mean_squared_error: 0.0837 - val_loss: 0.0768 - val_mean_absolute_error: 0.2169 - val_mean_squared_error: 0.0768 - 10s/epoch - 21ms/step
# Epoch 36/700
#
# Epoch 36: val_loss did not improve from 0.07670
# 479/479 - 9s - loss: 0.0842 - mean_absolute_error: 0.2330 - mean_squared_error: 0.0842 - val_loss: 0.0767 - val_mean_absolute_error: 0.2169 - val_mean_squared_error: 0.0767 - 9s/epoch - 20ms/step
# Epoch 37/700
#
# Epoch 37: val_loss did not improve from 0.07670
# 479/479 - 9s - loss: 0.0840 - mean_absolute_error: 0.2322 - mean_squared_error: 0.0840 - val_loss: 0.0768 - val_mean_absolute_error: 0.2174 - val_mean_squared_error: 0.0768 - 9s/epoch - 19ms/step
# Epoch 38/700
#
# Epoch 38: val_loss did not improve from 0.07670
# 479/479 - 9s - loss: 0.0830 - mean_absolute_error: 0.2309 - mean_squared_error: 0.0830 - val_loss: 0.0771 - val_mean_absolute_error: 0.2189 - val_mean_squared_error: 0.0771 - 9s/epoch - 19ms/step
# Epoch 39/700
#
# Epoch 39: val_loss improved from 0.07670 to 0.07631, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.0828 - mean_absolute_error: 0.2303 - mean_squared_error: 0.0828 - val_loss: 0.0763 - val_mean_absolute_error: 0.2145 - val_mean_squared_error: 0.0763 - 10s/epoch - 20ms/step
# Epoch 40/700
#
# Epoch 40: val_loss did not improve from 0.07631
# 479/479 - 9s - loss: 0.0827 - mean_absolute_error: 0.2304 - mean_squared_error: 0.0827 - val_loss: 0.0768 - val_mean_absolute_error: 0.2179 - val_mean_squared_error: 0.0768 - 9s/epoch - 20ms/step
# Epoch 41/700
#
# Epoch 41: val_loss did not improve from 0.07631
# 479/479 - 9s - loss: 0.0825 - mean_absolute_error: 0.2296 - mean_squared_error: 0.0825 - val_loss: 0.0770 - val_mean_absolute_error: 0.2187 - val_mean_squared_error: 0.0770 - 9s/epoch - 20ms/step
# Epoch 42/700
#
# Epoch 42: val_loss did not improve from 0.07631
# 479/479 - 9s - loss: 0.0822 - mean_absolute_error: 0.2292 - mean_squared_error: 0.0822 - val_loss: 0.0768 - val_mean_absolute_error: 0.2183 - val_mean_squared_error: 0.0768 - 9s/epoch - 19ms/step
# Epoch 43/700
#
# Epoch 43: val_loss improved from 0.07631 to 0.07609, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.0817 - mean_absolute_error: 0.2283 - mean_squared_error: 0.0817 - val_loss: 0.0761 - val_mean_absolute_error: 0.2130 - val_mean_squared_error: 0.0761 - 10s/epoch - 20ms/step
# Epoch 44/700
#
# Epoch 44: val_loss did not improve from 0.07609
# 479/479 - 9s - loss: 0.0815 - mean_absolute_error: 0.2277 - mean_squared_error: 0.0815 - val_loss: 0.0768 - val_mean_absolute_error: 0.2165 - val_mean_squared_error: 0.0768 - 9s/epoch - 19ms/step
# Epoch 45/700
#
# Epoch 45: val_loss did not improve from 0.07609
# 479/479 - 9s - loss: 0.0813 - mean_absolute_error: 0.2269 - mean_squared_error: 0.0813 - val_loss: 0.0765 - val_mean_absolute_error: 0.2137 - val_mean_squared_error: 0.0765 - 9s/epoch - 19ms/step
# Epoch 46/700
#
# Epoch 46: val_loss did not improve from 0.07609
# 479/479 - 9s - loss: 0.0814 - mean_absolute_error: 0.2265 - mean_squared_error: 0.0814 - val_loss: 0.0765 - val_mean_absolute_error: 0.2176 - val_mean_squared_error: 0.0765 - 9s/epoch - 20ms/step
# Epoch 47/700
#
# Epoch 47: val_loss did not improve from 0.07609
# 479/479 - 9s - loss: 0.0814 - mean_absolute_error: 0.2272 - mean_squared_error: 0.0814 - val_loss: 0.0772 - val_mean_absolute_error: 0.2199 - val_mean_squared_error: 0.0772 - 9s/epoch - 20ms/step
# Epoch 48/700
#
# Epoch 48: val_loss improved from 0.07609 to 0.07604, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.0807 - mean_absolute_error: 0.2258 - mean_squared_error: 0.0807 - val_loss: 0.0760 - val_mean_absolute_error: 0.2117 - val_mean_squared_error: 0.0760 - 10s/epoch - 20ms/step
# Epoch 49/700
#
# Epoch 49: val_loss did not improve from 0.07604
# 479/479 - 9s - loss: 0.0807 - mean_absolute_error: 0.2256 - mean_squared_error: 0.0807 - val_loss: 0.0771 - val_mean_absolute_error: 0.2193 - val_mean_squared_error: 0.0771 - 9s/epoch - 20ms/step
# Epoch 50/700
#
# Epoch 50: val_loss did not improve from 0.07604
# 479/479 - 9s - loss: 0.0808 - mean_absolute_error: 0.2261 - mean_squared_error: 0.0808 - val_loss: 0.0769 - val_mean_absolute_error: 0.2186 - val_mean_squared_error: 0.0769 - 9s/epoch - 20ms/step
# Epoch 51/700
#
# Epoch 51: val_loss did not improve from 0.07604
# 479/479 - 9s - loss: 0.0804 - mean_absolute_error: 0.2244 - mean_squared_error: 0.0804 - val_loss: 0.0762 - val_mean_absolute_error: 0.2145 - val_mean_squared_error: 0.0762 - 9s/epoch - 20ms/step
# Epoch 52/700
#
# Epoch 52: val_loss did not improve from 0.07604
# 479/479 - 9s - loss: 0.0803 - mean_absolute_error: 0.2247 - mean_squared_error: 0.0803 - val_loss: 0.0765 - val_mean_absolute_error: 0.2155 - val_mean_squared_error: 0.0765 - 9s/epoch - 20ms/step
# Epoch 53/700
#
# Epoch 53: val_loss did not improve from 0.07604
# 479/479 - 10s - loss: 0.0801 - mean_absolute_error: 0.2240 - mean_squared_error: 0.0801 - val_loss: 0.0763 - val_mean_absolute_error: 0.2142 - val_mean_squared_error: 0.0763 - 10s/epoch - 20ms/step
# Epoch 54/700
#
# Epoch 54: val_loss did not improve from 0.07604
# 479/479 - 10s - loss: 0.0803 - mean_absolute_error: 0.2248 - mean_squared_error: 0.0803 - val_loss: 0.0762 - val_mean_absolute_error: 0.2142 - val_mean_squared_error: 0.0762 - 10s/epoch - 20ms/step
# Epoch 55/700
#
# Epoch 55: val_loss did not improve from 0.07604
# 479/479 - 9s - loss: 0.0802 - mean_absolute_error: 0.2241 - mean_squared_error: 0.0802 - val_loss: 0.0762 - val_mean_absolute_error: 0.2153 - val_mean_squared_error: 0.0762 - 9s/epoch - 19ms/step
# Epoch 56/700
#
# Epoch 56: val_loss did not improve from 0.07604
# 479/479 - 9s - loss: 0.0801 - mean_absolute_error: 0.2244 - mean_squared_error: 0.0801 - val_loss: 0.0767 - val_mean_absolute_error: 0.2187 - val_mean_squared_error: 0.0767 - 9s/epoch - 20ms/step
# Epoch 57/700
#
# Epoch 57: val_loss improved from 0.07604 to 0.07593, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.0797 - mean_absolute_error: 0.2232 - mean_squared_error: 0.0797 - val_loss: 0.0759 - val_mean_absolute_error: 0.2122 - val_mean_squared_error: 0.0759 - 10s/epoch - 20ms/step
# Epoch 58/700
#
# Epoch 58: val_loss did not improve from 0.07593
# 479/479 - 9s - loss: 0.0791 - mean_absolute_error: 0.2219 - mean_squared_error: 0.0791 - val_loss: 0.0761 - val_mean_absolute_error: 0.2139 - val_mean_squared_error: 0.0761 - 9s/epoch - 20ms/step
# Epoch 59/700
#
# Epoch 59: val_loss improved from 0.07593 to 0.07575, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.0798 - mean_absolute_error: 0.2236 - mean_squared_error: 0.0798 - val_loss: 0.0758 - val_mean_absolute_error: 0.2102 - val_mean_squared_error: 0.0758 - 10s/epoch - 20ms/step
# Epoch 60/700
#
# Epoch 60: val_loss did not improve from 0.07575
# 479/479 - 10s - loss: 0.0795 - mean_absolute_error: 0.2225 - mean_squared_error: 0.0795 - val_loss: 0.0761 - val_mean_absolute_error: 0.2109 - val_mean_squared_error: 0.0761 - 10s/epoch - 20ms/step
# Epoch 61/700
#
# Epoch 61: val_loss did not improve from 0.07575
# 479/479 - 10s - loss: 0.0798 - mean_absolute_error: 0.2230 - mean_squared_error: 0.0798 - val_loss: 0.0761 - val_mean_absolute_error: 0.2133 - val_mean_squared_error: 0.0761 - 10s/epoch - 20ms/step
# Epoch 62/700
#
# Epoch 62: val_loss did not improve from 0.07575
# 479/479 - 9s - loss: 0.0790 - mean_absolute_error: 0.2215 - mean_squared_error: 0.0790 - val_loss: 0.0758 - val_mean_absolute_error: 0.2111 - val_mean_squared_error: 0.0758 - 9s/epoch - 20ms/step
# Epoch 63/700
#
# Epoch 63: val_loss did not improve from 0.07575
# 479/479 - 11s - loss: 0.0791 - mean_absolute_error: 0.2218 - mean_squared_error: 0.0791 - val_loss: 0.0760 - val_mean_absolute_error: 0.2135 - val_mean_squared_error: 0.0760 - 11s/epoch - 23ms/step
# Epoch 64/700
#
# Epoch 64: val_loss did not improve from 0.07575
# 479/479 - 10s - loss: 0.0790 - mean_absolute_error: 0.2213 - mean_squared_error: 0.0790 - val_loss: 0.0759 - val_mean_absolute_error: 0.2115 - val_mean_squared_error: 0.0759 - 10s/epoch - 20ms/step
# Epoch 65/700
#
# Epoch 65: val_loss did not improve from 0.07575
# 479/479 - 10s - loss: 0.0792 - mean_absolute_error: 0.2215 - mean_squared_error: 0.0792 - val_loss: 0.0760 - val_mean_absolute_error: 0.2127 - val_mean_squared_error: 0.0760 - 10s/epoch - 20ms/step
# Epoch 66/700
#
# Epoch 66: val_loss did not improve from 0.07575
# 479/479 - 9s - loss: 0.0792 - mean_absolute_error: 0.2213 - mean_squared_error: 0.0792 - val_loss: 0.0763 - val_mean_absolute_error: 0.2164 - val_mean_squared_error: 0.0763 - 9s/epoch - 20ms/step
# Epoch 67/700
#
# Epoch 67: val_loss did not improve from 0.07575
# 479/479 - 10s - loss: 0.0787 - mean_absolute_error: 0.2207 - mean_squared_error: 0.0787 - val_loss: 0.0762 - val_mean_absolute_error: 0.2140 - val_mean_squared_error: 0.0762 - 10s/epoch - 20ms/step
# Epoch 68/700
#
# Epoch 68: val_loss did not improve from 0.07575
# 479/479 - 10s - loss: 0.0788 - mean_absolute_error: 0.2211 - mean_squared_error: 0.0788 - val_loss: 0.0760 - val_mean_absolute_error: 0.2135 - val_mean_squared_error: 0.0760 - 10s/epoch - 20ms/step
# Epoch 69/700
#
# Epoch 69: val_loss did not improve from 0.07575
# 479/479 - 10s - loss: 0.0786 - mean_absolute_error: 0.2205 - mean_squared_error: 0.0786 - val_loss: 0.0759 - val_mean_absolute_error: 0.2129 - val_mean_squared_error: 0.0759 - 10s/epoch - 20ms/step
# Epoch 70/700
#
# Epoch 70: val_loss improved from 0.07575 to 0.07543, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.0784 - mean_absolute_error: 0.2202 - mean_squared_error: 0.0784 - val_loss: 0.0754 - val_mean_absolute_error: 0.2076 - val_mean_squared_error: 0.0754 - 10s/epoch - 21ms/step
# Epoch 71/700
#
# Epoch 71: val_loss did not improve from 0.07543
# 479/479 - 10s - loss: 0.0786 - mean_absolute_error: 0.2203 - mean_squared_error: 0.0786 - val_loss: 0.0761 - val_mean_absolute_error: 0.2140 - val_mean_squared_error: 0.0761 - 10s/epoch - 20ms/step
# Epoch 72/700
#
# Epoch 72: val_loss did not improve from 0.07543
# 479/479 - 10s - loss: 0.0785 - mean_absolute_error: 0.2198 - mean_squared_error: 0.0785 - val_loss: 0.0757 - val_mean_absolute_error: 0.2102 - val_mean_squared_error: 0.0757 - 10s/epoch - 20ms/step
# Epoch 73/700
#
# Epoch 73: val_loss did not improve from 0.07543
# 479/479 - 10s - loss: 0.0787 - mean_absolute_error: 0.2203 - mean_squared_error: 0.0787 - val_loss: 0.0758 - val_mean_absolute_error: 0.2109 - val_mean_squared_error: 0.0758 - 10s/epoch - 20ms/step
# Epoch 74/700
#
# Epoch 74: val_loss did not improve from 0.07543
# 479/479 - 10s - loss: 0.0781 - mean_absolute_error: 0.2192 - mean_squared_error: 0.0781 - val_loss: 0.0757 - val_mean_absolute_error: 0.2099 - val_mean_squared_error: 0.0757 - 10s/epoch - 20ms/step
# Epoch 75/700
#
# Epoch 75: val_loss did not improve from 0.07543
# 479/479 - 10s - loss: 0.0783 - mean_absolute_error: 0.2193 - mean_squared_error: 0.0783 - val_loss: 0.0760 - val_mean_absolute_error: 0.2135 - val_mean_squared_error: 0.0760 - 10s/epoch - 20ms/step
# Epoch 76/700
#
# Epoch 76: val_loss did not improve from 0.07543
# 479/479 - 10s - loss: 0.0785 - mean_absolute_error: 0.2204 - mean_squared_error: 0.0785 - val_loss: 0.0759 - val_mean_absolute_error: 0.2107 - val_mean_squared_error: 0.0759 - 10s/epoch - 20ms/step
# Epoch 77/700
#
# Epoch 77: val_loss did not improve from 0.07543
# 479/479 - 10s - loss: 0.0786 - mean_absolute_error: 0.2200 - mean_squared_error: 0.0786 - val_loss: 0.0762 - val_mean_absolute_error: 0.2137 - val_mean_squared_error: 0.0762 - 10s/epoch - 20ms/step
# Epoch 78/700
#
# Epoch 78: val_loss did not improve from 0.07543
# 479/479 - 10s - loss: 0.0784 - mean_absolute_error: 0.2199 - mean_squared_error: 0.0784 - val_loss: 0.0756 - val_mean_absolute_error: 0.2100 - val_mean_squared_error: 0.0756 - 10s/epoch - 20ms/step
# Epoch 79/700
#
# Epoch 79: val_loss did not improve from 0.07543
# 479/479 - 10s - loss: 0.0782 - mean_absolute_error: 0.2191 - mean_squared_error: 0.0782 - val_loss: 0.0761 - val_mean_absolute_error: 0.2139 - val_mean_squared_error: 0.0761 - 10s/epoch - 20ms/step
# Epoch 80/700
#
# Epoch 80: val_loss did not improve from 0.07543
# 479/479 - 10s - loss: 0.0783 - mean_absolute_error: 0.2194 - mean_squared_error: 0.0783 - val_loss: 0.0760 - val_mean_absolute_error: 0.2119 - val_mean_squared_error: 0.0760 - 10s/epoch - 20ms/step
# Epoch 81/700
#
# Epoch 81: val_loss did not improve from 0.07543
# 479/479 - 10s - loss: 0.0788 - mean_absolute_error: 0.2203 - mean_squared_error: 0.0788 - val_loss: 0.0761 - val_mean_absolute_error: 0.2129 - val_mean_squared_error: 0.0761 - 10s/epoch - 20ms/step
# Epoch 82/700
#
# Epoch 82: val_loss did not improve from 0.07543
# 479/479 - 10s - loss: 0.0778 - mean_absolute_error: 0.2185 - mean_squared_error: 0.0778 - val_loss: 0.0759 - val_mean_absolute_error: 0.2128 - val_mean_squared_error: 0.0759 - 10s/epoch - 20ms/step
# Epoch 83/700
#
# Epoch 83: val_loss did not improve from 0.07543
# 479/479 - 10s - loss: 0.0779 - mean_absolute_error: 0.2183 - mean_squared_error: 0.0779 - val_loss: 0.0758 - val_mean_absolute_error: 0.2110 - val_mean_squared_error: 0.0758 - 10s/epoch - 20ms/step
# Epoch 84/700
#
# Epoch 84: val_loss improved from 0.07543 to 0.07538, saving model to best_combined_model.h5
# 479/479 - 10s - loss: 0.0780 - mean_absolute_error: 0.2187 - mean_squared_error: 0.0780 - val_loss: 0.0754 - val_mean_absolute_error: 0.2071 - val_mean_squared_error: 0.0754 - 10s/epoch - 21ms/step
# Epoch 85/700
#
# Epoch 85: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0784 - mean_absolute_error: 0.2191 - mean_squared_error: 0.0784 - val_loss: 0.0757 - val_mean_absolute_error: 0.2113 - val_mean_squared_error: 0.0757 - 10s/epoch - 20ms/step
# Epoch 86/700
#
# Epoch 86: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0780 - mean_absolute_error: 0.2183 - mean_squared_error: 0.0780 - val_loss: 0.0758 - val_mean_absolute_error: 0.2121 - val_mean_squared_error: 0.0758 - 10s/epoch - 20ms/step
# Epoch 87/700
#
# Epoch 87: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0780 - mean_absolute_error: 0.2186 - mean_squared_error: 0.0780 - val_loss: 0.0758 - val_mean_absolute_error: 0.2110 - val_mean_squared_error: 0.0758 - 10s/epoch - 20ms/step
# Epoch 88/700
#
# Epoch 88: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0780 - mean_absolute_error: 0.2183 - mean_squared_error: 0.0780 - val_loss: 0.0762 - val_mean_absolute_error: 0.2096 - val_mean_squared_error: 0.0762 - 10s/epoch - 20ms/step
# Epoch 89/700
#
# Epoch 89: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0778 - mean_absolute_error: 0.2178 - mean_squared_error: 0.0778 - val_loss: 0.0755 - val_mean_absolute_error: 0.2098 - val_mean_squared_error: 0.0755 - 10s/epoch - 20ms/step
# Epoch 90/700
#
# Epoch 90: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0775 - mean_absolute_error: 0.2169 - mean_squared_error: 0.0775 - val_loss: 0.0757 - val_mean_absolute_error: 0.2105 - val_mean_squared_error: 0.0757 - 10s/epoch - 20ms/step
# Epoch 91/700
#
# Epoch 91: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0779 - mean_absolute_error: 0.2178 - mean_squared_error: 0.0779 - val_loss: 0.0763 - val_mean_absolute_error: 0.2165 - val_mean_squared_error: 0.0763 - 10s/epoch - 20ms/step
# Epoch 92/700
#
# Epoch 92: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0775 - mean_absolute_error: 0.2174 - mean_squared_error: 0.0775 - val_loss: 0.0757 - val_mean_absolute_error: 0.2108 - val_mean_squared_error: 0.0757 - 10s/epoch - 21ms/step
# Epoch 93/700
#
# Epoch 93: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0776 - mean_absolute_error: 0.2173 - mean_squared_error: 0.0776 - val_loss: 0.0758 - val_mean_absolute_error: 0.2116 - val_mean_squared_error: 0.0758 - 10s/epoch - 20ms/step
# Epoch 94/700
#
# Epoch 94: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0781 - mean_absolute_error: 0.2184 - mean_squared_error: 0.0781 - val_loss: 0.0758 - val_mean_absolute_error: 0.2091 - val_mean_squared_error: 0.0758 - 10s/epoch - 20ms/step
# Epoch 95/700
#
# Epoch 95: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0785 - mean_absolute_error: 0.2190 - mean_squared_error: 0.0785 - val_loss: 0.0757 - val_mean_absolute_error: 0.2095 - val_mean_squared_error: 0.0757 - 10s/epoch - 20ms/step
# Epoch 96/700
#
# Epoch 96: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0776 - mean_absolute_error: 0.2176 - mean_squared_error: 0.0776 - val_loss: 0.0757 - val_mean_absolute_error: 0.2112 - val_mean_squared_error: 0.0757 - 10s/epoch - 20ms/step
# Epoch 97/700
#
# Epoch 97: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0777 - mean_absolute_error: 0.2179 - mean_squared_error: 0.0777 - val_loss: 0.0763 - val_mean_absolute_error: 0.2122 - val_mean_squared_error: 0.0763 - 10s/epoch - 20ms/step
# Epoch 98/700
#
# Epoch 98: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0777 - mean_absolute_error: 0.2170 - mean_squared_error: 0.0777 - val_loss: 0.0758 - val_mean_absolute_error: 0.2128 - val_mean_squared_error: 0.0758 - 10s/epoch - 20ms/step
# Epoch 99/700
#
# Epoch 99: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0777 - mean_absolute_error: 0.2173 - mean_squared_error: 0.0777 - val_loss: 0.0756 - val_mean_absolute_error: 0.2075 - val_mean_squared_error: 0.0756 - 10s/epoch - 20ms/step
# Epoch 100/700
#
# Epoch 100: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0777 - mean_absolute_error: 0.2175 - mean_squared_error: 0.0777 - val_loss: 0.0761 - val_mean_absolute_error: 0.2126 - val_mean_squared_error: 0.0761 - 10s/epoch - 20ms/step
# Epoch 101/700
#
# Epoch 101: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0774 - mean_absolute_error: 0.2169 - mean_squared_error: 0.0774 - val_loss: 0.0759 - val_mean_absolute_error: 0.2101 - val_mean_squared_error: 0.0759 - 10s/epoch - 20ms/step
# Epoch 102/700
#
# Epoch 102: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0773 - mean_absolute_error: 0.2164 - mean_squared_error: 0.0773 - val_loss: 0.0756 - val_mean_absolute_error: 0.2075 - val_mean_squared_error: 0.0756 - 10s/epoch - 20ms/step
# Epoch 103/700
#
# Epoch 103: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0773 - mean_absolute_error: 0.2162 - mean_squared_error: 0.0773 - val_loss: 0.0758 - val_mean_absolute_error: 0.2114 - val_mean_squared_error: 0.0758 - 10s/epoch - 20ms/step
# Epoch 104/700
#
# Epoch 104: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0776 - mean_absolute_error: 0.2167 - mean_squared_error: 0.0776 - val_loss: 0.0763 - val_mean_absolute_error: 0.2113 - val_mean_squared_error: 0.0763 - 10s/epoch - 20ms/step
# Epoch 105/700
#
# Epoch 105: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0775 - mean_absolute_error: 0.2167 - mean_squared_error: 0.0775 - val_loss: 0.0760 - val_mean_absolute_error: 0.2128 - val_mean_squared_error: 0.0760 - 10s/epoch - 20ms/step
# Epoch 106/700
#
# Epoch 106: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0773 - mean_absolute_error: 0.2163 - mean_squared_error: 0.0773 - val_loss: 0.0757 - val_mean_absolute_error: 0.2109 - val_mean_squared_error: 0.0757 - 10s/epoch - 20ms/step
# Epoch 107/700
#
# Epoch 107: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0776 - mean_absolute_error: 0.2173 - mean_squared_error: 0.0776 - val_loss: 0.0755 - val_mean_absolute_error: 0.2089 - val_mean_squared_error: 0.0755 - 10s/epoch - 20ms/step
# Epoch 108/700
#
# Epoch 108: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0771 - mean_absolute_error: 0.2161 - mean_squared_error: 0.0771 - val_loss: 0.0755 - val_mean_absolute_error: 0.2093 - val_mean_squared_error: 0.0755 - 10s/epoch - 20ms/step
# Epoch 109/700
#
# Epoch 109: val_loss did not improve from 0.07538
# 479/479 - 10s - loss: 0.0777 - mean_absolute_error: 0.2168 - mean_squared_error: 0.0777 - val_loss: 0.0759 - val_mean_absolute_error: 0.2131 - val_mean_squared_error: 0.0759 - 10s/epoch - 20ms/step
# Epoch 109: early stopping

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.xlim(0,90)
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model = keras.models.load_model('best_combined_model.h5')

# %%
model.evaluate(x_test,y_test)
# Out:
# 43/43 [==============================] - 11s 5ms/step - loss: 0.0748 - mean_absolute_error: 0.2040 - mean_squared_error: 0.0748
# [0.0748201534152031, 0.20396794378757477, 0.0748201534152031]

# %%
res = model.predict(x_test)

# %%
plt.plot(res[3])

# %%
plt.plot(y_test[3])
