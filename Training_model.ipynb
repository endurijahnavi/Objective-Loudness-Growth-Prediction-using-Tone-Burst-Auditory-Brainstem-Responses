# %%
import numpy as np
import tensorflow as tf
import tensorflow
from tensorflow import keras
from keras import layers
from tensorflow.keras.utils import plot_model
import pandas as pd
import matplotlib.pyplot as plt
from keras import regularizers, optimizers
from keras.layers import Dense, Dropout, Input
from keras.models import Sequential, load_model
from keras.callbacks import ModelCheckpoint
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError,MeanSquaredError
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping

# %%
pip install visualkeras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: visualkeras in /usr/local/lib/python3.7/dist-packages (0.0.2)
# Requirement already satisfied: aggdraw>=1.3.11 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (1.3.15)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (1.21.6)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (7.1.2)

# %%
import visualkeras

# %%
ewt_signal_length = 126
n_levels = 10
memory_units = int(32)
batchsize = 128

# %%
def custom_layer1(tensor):
  return tensor[:,0,:]
def custom_layer2(tensor):
  return tensor[:,1,:]
def custom_layer3(tensor):
  return tensor[:,2,:]
def custom_layer4(tensor):
  return tensor[:,3,:]
def custom_layer5(tensor):
  return tensor[:,4,:]
def custom_layer6(tensor):
  return tensor[:,5,:]
def custom_layer7(tensor):
  return tensor[:,6,:]
def custom_layer8(tensor):
  return tensor[:,7,:]
def custom_layer9(tensor):
  return tensor[:,8,:]
def custom_layer10(tensor):
  return tensor[:,9,:]

# %%
ewt_signal_length = 126
n_levels = 10
memory_units1 = int(16)
memory_units2 = int(16)
# batchsize = 256
batchsize = 256
def custom_layer1(tensor):
  return tensor[:,0,:]
def custom_layer2(tensor):
  return tensor[:,1,:]
def custom_layer3(tensor):
  return tensor[:,2,:]
def custom_layer4(tensor):
  return tensor[:,3,:]
def custom_layer5(tensor):
  return tensor[:,4,:]
def custom_layer6(tensor):
  return tensor[:,5,:]
def custom_layer7(tensor):
  return tensor[:,6,:]
def custom_layer8(tensor):
  return tensor[:,7,:]
def custom_layer9(tensor):
  return tensor[:,8,:]
def custom_layer10(tensor):
  return tensor[:,9,:]

input = keras.Input(shape = (n_levels,ewt_signal_length))
input_data_model_1 = tensorflow.keras.layers.Lambda(custom_layer1, name="lambda_layer1")(input)
input_data_model_1 = layers.Reshape((1,ewt_signal_length))(input_data_model_1)
input_data_model_2 = tensorflow.keras.layers.Lambda(custom_layer2, name="lambda_layer2")(input)
input_data_model_2 = layers.Reshape((1,ewt_signal_length))(input_data_model_2)
input_data_model_3 = tensorflow.keras.layers.Lambda(custom_layer3, name="lambda_layer3")(input)
input_data_model_3 = layers.Reshape((1,ewt_signal_length))(input_data_model_3)
input_data_model_4 = tensorflow.keras.layers.Lambda(custom_layer4, name="lambda_layer4")(input)
input_data_model_4 = layers.Reshape((1,ewt_signal_length))(input_data_model_4)
input_data_model_5 = tensorflow.keras.layers.Lambda(custom_layer5, name="lambda_layer5")(input)
input_data_model_5 = layers.Reshape((1,ewt_signal_length))(input_data_model_5)
input_data_model_6 = tensorflow.keras.layers.Lambda(custom_layer6, name="lambda_layer6")(input)
input_data_model_6 = layers.Reshape((1,ewt_signal_length))(input_data_model_6)
input_data_model_7 = tensorflow.keras.layers.Lambda(custom_layer7, name="lambda_layer7")(input)
input_data_model_7 = layers.Reshape((1,ewt_signal_length))(input_data_model_7)
input_data_model_8 = tensorflow.keras.layers.Lambda(custom_layer8, name="lambda_layer8")(input)
input_data_model_8 = layers.Reshape((1,ewt_signal_length))(input_data_model_8)
input_data_model_9 = tensorflow.keras.layers.Lambda(custom_layer9, name="lambda_layer9")(input)
input_data_model_9 = layers.Reshape((1,ewt_signal_length))(input_data_model_9)
input_data_model_10 = tensorflow.keras.layers.Lambda(custom_layer10, name="lambda_layer10")(input)
input_data_model_10 = layers.Reshape((1,ewt_signal_length))(input_data_model_10)
for i in range(n_levels):
  globals()[f"input_data_model_{i+1}"] = layers.BatchNormalization(scale = False,center = False)(globals()[f"input_data_model_{i+1}"])
  globals()[f"x{i+1}"]= layers.LSTM(memory_units1,return_sequences = True)(globals()[f"input_data_model_{i+1}"])
  globals()[f"x{i+1}"] = layers.LSTM(int(memory_units1/2))(globals()[f"x{i+1}"])
  globals()[f"x{i+1}"] = layers.Dropout(0.5)(globals()[f"x{i+1}"])
  globals()[f"output_{i+1}"] = layers.Dense(1,activation = 'linear')(globals()[f"x{i+1}"])

outputs_models = layers.concatenate([output_1, output_2,output_3,output_4,output_5,output_6,output_7,output_8,output_9,output_10])
outputs_models = layers.BatchNormalization(scale = False,center = False)(outputs_models)
# final_output = layers.Dense(1)(outputs_models)
z = layers.Reshape((1,n_levels))(outputs_models)
z = layers.LSTM(memory_units2,return_sequences = True)(z)
z = layers.LSTM(int(memory_units2/2))(z)
final_output = layers.Dense(1,activation = 'linear')(z)
#z = layers.RNN(layers.LSTMCell(32),return_sequences = True)(outputs_models)
# z = layers.RNN(layers.LSTMCell(16))(z)
# final_output = layers.Dense(1)(z)
model = keras.Model(inputs = input,outputs = final_output,name = 'my_model')

# %%
model.summary()
# Out:
# Model: "my_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 10, 126)]    0           []
#
#  lambda_layer1 (Lambda)         (None, 126)          0           ['input_1[0][0]']
#
#  lambda_layer2 (Lambda)         (None, 126)          0           ['input_1[0][0]']
#
#  lambda_layer3 (Lambda)         (None, 126)          0           ['input_1[0][0]']
#
#  lambda_layer4 (Lambda)         (None, 126)          0           ['input_1[0][0]']
#
#  lambda_layer5 (Lambda)         (None, 126)          0           ['input_1[0][0]']
#
#  lambda_layer6 (Lambda)         (None, 126)          0           ['input_1[0][0]']
#
#  lambda_layer7 (Lambda)         (None, 126)          0           ['input_1[0][0]']
#
#  lambda_layer8 (Lambda)         (None, 126)          0           ['input_1[0][0]']
#
#  lambda_layer9 (Lambda)         (None, 126)          0           ['input_1[0][0]']
#
#  lambda_layer10 (Lambda)        (None, 126)          0           ['input_1[0][0]']
#
#  reshape (Reshape)              (None, 1, 126)       0           ['lambda_layer1[0][0]']
#
#  reshape_1 (Reshape)            (None, 1, 126)       0           ['lambda_layer2[0][0]']
#
#  reshape_2 (Reshape)            (None, 1, 126)       0           ['lambda_layer3[0][0]']
#
#  reshape_3 (Reshape)            (None, 1, 126)       0           ['lambda_layer4[0][0]']
#
#  reshape_4 (Reshape)            (None, 1, 126)       0           ['lambda_layer5[0][0]']
#
#  reshape_5 (Reshape)            (None, 1, 126)       0           ['lambda_layer6[0][0]']
#
#  reshape_6 (Reshape)            (None, 1, 126)       0           ['lambda_layer7[0][0]']
#
#  reshape_7 (Reshape)            (None, 1, 126)       0           ['lambda_layer8[0][0]']
#
#  reshape_8 (Reshape)            (None, 1, 126)       0           ['lambda_layer9[0][0]']
#
#  reshape_9 (Reshape)            (None, 1, 126)       0           ['lambda_layer10[0][0]']
#
#  batch_normalization (BatchNorm  (None, 1, 126)      252         ['reshape[0][0]']
#  alization)
#
#  batch_normalization_1 (BatchNo  (None, 1, 126)      252         ['reshape_1[0][0]']
#  rmalization)
#
#  batch_normalization_2 (BatchNo  (None, 1, 126)      252         ['reshape_2[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 1, 126)      252         ['reshape_3[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 1, 126)      252         ['reshape_4[0][0]']
#  rmalization)
#
#  batch_normalization_5 (BatchNo  (None, 1, 126)      252         ['reshape_5[0][0]']
#  rmalization)
#
#  batch_normalization_6 (BatchNo  (None, 1, 126)      252         ['reshape_6[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 1, 126)      252         ['reshape_7[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, 1, 126)      252         ['reshape_8[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 1, 126)      252         ['reshape_9[0][0]']
#  rmalization)
#
#  lstm (LSTM)                    (None, 1, 16)        9152        ['batch_normalization[0][0]']
#
#  lstm_2 (LSTM)                  (None, 1, 16)        9152        ['batch_normalization_1[0][0]']
#
#  lstm_4 (LSTM)                  (None, 1, 16)        9152        ['batch_normalization_2[0][0]']
#
#  lstm_6 (LSTM)                  (None, 1, 16)        9152        ['batch_normalization_3[0][0]']
#
#  lstm_8 (LSTM)                  (None, 1, 16)        9152        ['batch_normalization_4[0][0]']
#
#  lstm_10 (LSTM)                 (None, 1, 16)        9152        ['batch_normalization_5[0][0]']
#
#  lstm_12 (LSTM)                 (None, 1, 16)        9152        ['batch_normalization_6[0][0]']
#
#  lstm_14 (LSTM)                 (None, 1, 16)        9152        ['batch_normalization_7[0][0]']
#
#  lstm_16 (LSTM)                 (None, 1, 16)        9152        ['batch_normalization_8[0][0]']
#
#  lstm_18 (LSTM)                 (None, 1, 16)        9152        ['batch_normalization_9[0][0]']
#
#  lstm_1 (LSTM)                  (None, 8)            800         ['lstm[0][0]']
#
#  lstm_3 (LSTM)                  (None, 8)            800         ['lstm_2[0][0]']
#
#  lstm_5 (LSTM)                  (None, 8)            800         ['lstm_4[0][0]']
#
#  lstm_7 (LSTM)                  (None, 8)            800         ['lstm_6[0][0]']
#
#  lstm_9 (LSTM)                  (None, 8)            800         ['lstm_8[0][0]']
#
#  lstm_11 (LSTM)                 (None, 8)            800         ['lstm_10[0][0]']
#
#  lstm_13 (LSTM)                 (None, 8)            800         ['lstm_12[0][0]']
#
#  lstm_15 (LSTM)                 (None, 8)            800         ['lstm_14[0][0]']
#
#  lstm_17 (LSTM)                 (None, 8)            800         ['lstm_16[0][0]']
#
#  lstm_19 (LSTM)                 (None, 8)            800         ['lstm_18[0][0]']
#
#  dropout (Dropout)              (None, 8)            0           ['lstm_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 8)            0           ['lstm_3[0][0]']
#
#  dropout_2 (Dropout)            (None, 8)            0           ['lstm_5[0][0]']
#
#  dropout_3 (Dropout)            (None, 8)            0           ['lstm_7[0][0]']
#
#  dropout_4 (Dropout)            (None, 8)            0           ['lstm_9[0][0]']
#
#  dropout_5 (Dropout)            (None, 8)            0           ['lstm_11[0][0]']
#
#  dropout_6 (Dropout)            (None, 8)            0           ['lstm_13[0][0]']
#
#  dropout_7 (Dropout)            (None, 8)            0           ['lstm_15[0][0]']
#
#  dropout_8 (Dropout)            (None, 8)            0           ['lstm_17[0][0]']
#
#  dropout_9 (Dropout)            (None, 8)            0           ['lstm_19[0][0]']
#
#  dense (Dense)                  (None, 1)            9           ['dropout[0][0]']
#
#  dense_1 (Dense)                (None, 1)            9           ['dropout_1[0][0]']
#
#  dense_2 (Dense)                (None, 1)            9           ['dropout_2[0][0]']
#
#  dense_3 (Dense)                (None, 1)            9           ['dropout_3[0][0]']
#
#  dense_4 (Dense)                (None, 1)            9           ['dropout_4[0][0]']
#
#  dense_5 (Dense)                (None, 1)            9           ['dropout_5[0][0]']
#
#  dense_6 (Dense)                (None, 1)            9           ['dropout_6[0][0]']
#
#  dense_7 (Dense)                (None, 1)            9           ['dropout_7[0][0]']
#
#  dense_8 (Dense)                (None, 1)            9           ['dropout_8[0][0]']
#
#  dense_9 (Dense)                (None, 1)            9           ['dropout_9[0][0]']
#
#  concatenate (Concatenate)      (None, 10)           0           ['dense[0][0]',
#                                                                   'dense_1[0][0]',
#                                                                   'dense_2[0][0]',
#                                                                   'dense_3[0][0]',
#                                                                   'dense_4[0][0]',
#                                                                   'dense_5[0][0]',
#                                                                   'dense_6[0][0]',
#                                                                   'dense_7[0][0]',
#                                                                   'dense_8[0][0]',
#                                                                   'dense_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 10)          20          ['concatenate[0][0]']
#  ormalization)
#
#  reshape_10 (Reshape)           (None, 1, 10)        0           ['batch_normalization_10[0][0]']
#
#  lstm_20 (LSTM)                 (None, 1, 16)        1728        ['reshape_10[0][0]']
#
#  lstm_21 (LSTM)                 (None, 8)            800         ['lstm_20[0][0]']
#
#  dense_10 (Dense)               (None, 1)            9           ['lstm_21[0][0]']
#
# ==================================================================================================
# Total params: 104,687
# Trainable params: 102,147
# Non-trainable params: 2,540
# __________________________________________________________________________________________________

# %%
model.save('midsemreport.h5')

# %%
cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
model.summary()
# Out:
# Model: "my_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 10, 126)]    0           []
#
#  lambda_layer1 (Lambda)         (None, 126)          0           ['input_7[0][0]']
#
#  lambda_layer2 (Lambda)         (None, 126)          0           ['input_7[0][0]']
#
#  lambda_layer3 (Lambda)         (None, 126)          0           ['input_7[0][0]']
#
#  lambda_layer4 (Lambda)         (None, 126)          0           ['input_7[0][0]']
#
#  lambda_layer5 (Lambda)         (None, 126)          0           ['input_7[0][0]']
#
#  lambda_layer6 (Lambda)         (None, 126)          0           ['input_7[0][0]']
#
#  lambda_layer7 (Lambda)         (None, 126)          0           ['input_7[0][0]']
#
#  lambda_layer8 (Lambda)         (None, 126)          0           ['input_7[0][0]']
#
#  lambda_layer9 (Lambda)         (None, 126)          0           ['input_7[0][0]']
#
#  lambda_layer10 (Lambda)        (None, 126)          0           ['input_7[0][0]']
#
#  reshape_66 (Reshape)           (None, 1, 126)       0           ['lambda_layer1[0][0]']
#
#  reshape_67 (Reshape)           (None, 1, 126)       0           ['lambda_layer2[0][0]']
#
#  reshape_68 (Reshape)           (None, 1, 126)       0           ['lambda_layer3[0][0]']
#
#  reshape_69 (Reshape)           (None, 1, 126)       0           ['lambda_layer4[0][0]']
#
#  reshape_70 (Reshape)           (None, 1, 126)       0           ['lambda_layer5[0][0]']
#
#  reshape_71 (Reshape)           (None, 1, 126)       0           ['lambda_layer6[0][0]']
#
#  reshape_72 (Reshape)           (None, 1, 126)       0           ['lambda_layer7[0][0]']
#
#  reshape_73 (Reshape)           (None, 1, 126)       0           ['lambda_layer8[0][0]']
#
#  reshape_74 (Reshape)           (None, 1, 126)       0           ['lambda_layer9[0][0]']
#
#  reshape_75 (Reshape)           (None, 1, 126)       0           ['lambda_layer10[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 1, 126)      252         ['reshape_66[0][0]']
#  ormalization)
#
#  batch_normalization_67 (BatchN  (None, 1, 126)      252         ['reshape_67[0][0]']
#  ormalization)
#
#  batch_normalization_68 (BatchN  (None, 1, 126)      252         ['reshape_68[0][0]']
#  ormalization)
#
#  batch_normalization_69 (BatchN  (None, 1, 126)      252         ['reshape_69[0][0]']
#  ormalization)
#
#  batch_normalization_70 (BatchN  (None, 1, 126)      252         ['reshape_70[0][0]']
#  ormalization)
#
#  batch_normalization_71 (BatchN  (None, 1, 126)      252         ['reshape_71[0][0]']
#  ormalization)
#
#  batch_normalization_72 (BatchN  (None, 1, 126)      252         ['reshape_72[0][0]']
#  ormalization)
#
#  batch_normalization_73 (BatchN  (None, 1, 126)      252         ['reshape_73[0][0]']
#  ormalization)
#
#  batch_normalization_74 (BatchN  (None, 1, 126)      252         ['reshape_74[0][0]']
#  ormalization)
#
#  batch_normalization_75 (BatchN  (None, 1, 126)      252         ['reshape_75[0][0]']
#  ormalization)
#
#  lstm_132 (LSTM)                (None, 1, 16)        9152        ['batch_normalization_66[0][0]']
#
#  lstm_134 (LSTM)                (None, 1, 16)        9152        ['batch_normalization_67[0][0]']
#
#  lstm_136 (LSTM)                (None, 1, 16)        9152        ['batch_normalization_68[0][0]']
#
#  lstm_138 (LSTM)                (None, 1, 16)        9152        ['batch_normalization_69[0][0]']
#
#  lstm_140 (LSTM)                (None, 1, 16)        9152        ['batch_normalization_70[0][0]']
#
#  lstm_142 (LSTM)                (None, 1, 16)        9152        ['batch_normalization_71[0][0]']
#
#  lstm_144 (LSTM)                (None, 1, 16)        9152        ['batch_normalization_72[0][0]']
#
#  lstm_146 (LSTM)                (None, 1, 16)        9152        ['batch_normalization_73[0][0]']
#
#  lstm_148 (LSTM)                (None, 1, 16)        9152        ['batch_normalization_74[0][0]']
#
#  lstm_150 (LSTM)                (None, 1, 16)        9152        ['batch_normalization_75[0][0]']
#
#  lstm_133 (LSTM)                (None, 8)            800         ['lstm_132[0][0]']
#
#  lstm_135 (LSTM)                (None, 8)            800         ['lstm_134[0][0]']
#
#  lstm_137 (LSTM)                (None, 8)            800         ['lstm_136[0][0]']
#
#  lstm_139 (LSTM)                (None, 8)            800         ['lstm_138[0][0]']
#
#  lstm_141 (LSTM)                (None, 8)            800         ['lstm_140[0][0]']
#
#  lstm_143 (LSTM)                (None, 8)            800         ['lstm_142[0][0]']
#
#  lstm_145 (LSTM)                (None, 8)            800         ['lstm_144[0][0]']
#
#  lstm_147 (LSTM)                (None, 8)            800         ['lstm_146[0][0]']
#
#  lstm_149 (LSTM)                (None, 8)            800         ['lstm_148[0][0]']
#
#  lstm_151 (LSTM)                (None, 8)            800         ['lstm_150[0][0]']
#
#  dropout_50 (Dropout)           (None, 8)            0           ['lstm_133[0][0]']
#
#  dropout_51 (Dropout)           (None, 8)            0           ['lstm_135[0][0]']
#
#  dropout_52 (Dropout)           (None, 8)            0           ['lstm_137[0][0]']
#
#  dropout_53 (Dropout)           (None, 8)            0           ['lstm_139[0][0]']
#
#  dropout_54 (Dropout)           (None, 8)            0           ['lstm_141[0][0]']
#
#  dropout_55 (Dropout)           (None, 8)            0           ['lstm_143[0][0]']
#
#  dropout_56 (Dropout)           (None, 8)            0           ['lstm_145[0][0]']
#
#  dropout_57 (Dropout)           (None, 8)            0           ['lstm_147[0][0]']
#
#  dropout_58 (Dropout)           (None, 8)            0           ['lstm_149[0][0]']
#
#  dropout_59 (Dropout)           (None, 8)            0           ['lstm_151[0][0]']
#
#  dense_66 (Dense)               (None, 1)            9           ['dropout_50[0][0]']
#
#  dense_67 (Dense)               (None, 1)            9           ['dropout_51[0][0]']
#
#  dense_68 (Dense)               (None, 1)            9           ['dropout_52[0][0]']
#
#  dense_69 (Dense)               (None, 1)            9           ['dropout_53[0][0]']
#
#  dense_70 (Dense)               (None, 1)            9           ['dropout_54[0][0]']
#
#  dense_71 (Dense)               (None, 1)            9           ['dropout_55[0][0]']
#
#  dense_72 (Dense)               (None, 1)            9           ['dropout_56[0][0]']
#
#  dense_73 (Dense)               (None, 1)            9           ['dropout_57[0][0]']
#
#  dense_74 (Dense)               (None, 1)            9           ['dropout_58[0][0]']
#
#  dense_75 (Dense)               (None, 1)            9           ['dropout_59[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 10)           0           ['dense_66[0][0]',
#                                                                   'dense_67[0][0]',
#                                                                   'dense_68[0][0]',
#                                                                   'dense_69[0][0]',
#                                                                   'dense_70[0][0]',
#                                                                   'dense_71[0][0]',
#                                                                   'dense_72[0][0]',
#                                                                   'dense_73[0][0]',
#                                                                   'dense_74[0][0]',
#                                                                   'dense_75[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 10)          20          ['concatenate_6[0][0]']
#  ormalization)
#
#  reshape_76 (Reshape)           (None, 1, 10)        0           ['batch_normalization_76[0][0]']
#
#  lstm_152 (LSTM)                (None, 1, 16)        1728        ['reshape_76[0][0]']
#
#  lstm_153 (LSTM)                (None, 8)            800         ['lstm_152[0][0]']
#
#  dense_76 (Dense)               (None, 1)            9           ['lstm_153[0][0]']
#
# ==================================================================================================
# Total params: 104,687
# Trainable params: 102,147
# Non-trainable params: 2,540
# __________________________________________________________________________________________________

# %%
plot_model(model)

# %%
optimizer = keras.optimizers.Adam()

model.compile(loss='mean_squared_error', optimizer = optimizer,metrics = ['RootMeanSquaredError','MeanSquaredError','accuracy']) # Try SGD, adam, adagrad and compare!!!

# %%
# !pip3 install keras-visualizer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-visualizer
#   Downloading keras_visualizer-2.4-py3-none-any.whl (5.4 kB)
# Installing collected packages: keras-visualizer
# Successfully installed keras-visualizer-2.4

# %%
from keras_visualizer import visualizer 
visualizer(model, format='png', view=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-8d78ee4d9738> in <module>
#       1 from keras_visualizer import visualizer
# ----> 2 visualizer(model, format='png', view=True)
#
# /usr/local/lib/python3.7/dist-packages/keras_visualizer/__init__.py in visualizer(model, filename, format, view)
#     128                 c.node(str(n), label=f'Image\n{pxls[1]} x{pxls[2]} pixels\n{clrmap}', fontcolor='white', shape='square', style='filled', fillcolor=the_color)
#     129             else:
# --> 130                 raise ValueError('Keras Visualizer: Layer not supported for visualizing')
#     131
#     132         # Hidden Layers
#
# ValueError: Keras Visualizer: Layer not supported for visualizing

# %%
x = np.load('x_n1_my.npy')
y = np.load('y_n1_my.npy')
X = x.transpose()
x_train,x_test,y_train,y_test = train_test_split(X,y,train_size = 0.95)
optimizer = keras.optimizers.Adam()
model.compile(loss='mean_squared_error', optimizer = optimizer,metrics = ['RootMeanSquaredError','MeanSquaredError','accuracy']) # Try SGD, adam, adagrad and compare!!!
file = 'model_best.h5'
es = EarlyStopping(monitor='val_loss', mode='min', verbose=5, patience=10)
checkpoint = ModelCheckpoint(filepath=filepath, 
                             monitor='val_loss',
                             verbose=1, 
                             save_best_only=True,
                             mode='min')
callbacks = [checkpoint,es]
history = model.fit(x_train,y_train, epochs=700, batch_size=batchsize, verbose=2,validation_split = 0.2, callbacks = callbacks)
# Out:
# Epoch 1/700
#
# Epoch 1: val_loss improved from inf to 0.47481, saving model to /home/nitya/projects/LoudnessCurve(vineet)/best_model_full_dataset.hdf5
# 778/778 - 77s - loss: 0.4859 - root_mean_squared_error: 0.6971 - mean_squared_error: 0.4859 - accuracy: 0.0000e+00 - val_loss: 0.4748 - val_root_mean_squared_error: 0.6891 - val_mean_squared_error: 0.4748 - val_accuracy: 0.0000e+00 - 77s/epoch - 99ms/step
# Epoch 2/700
#
# Epoch 2: val_loss improved from 0.47481 to 0.47206, saving model to /home/nitya/projects/LoudnessCurve(vineet)/best_model_full_dataset.hdf5
# 778/778 - 21s - loss: 0.4721 - root_mean_squared_error: 0.6871 - mean_squared_error: 0.4721 - accuracy: 0.0000e+00 - val_loss: 0.4721 - val_root_mean_squared_error: 0.6871 - val_mean_squared_error: 0.4721 - val_accuracy: 0.0000e+00 - 21s/epoch - 27ms/step
# Epoch 3/700
#
# Epoch 3: val_loss did not improve from 0.47206
# 778/778 - 21s - loss: 0.4704 - root_mean_squared_error: 0.6859 - mean_squared_error: 0.4704 - accuracy: 0.0000e+00 - val_loss: 0.4735 - val_root_mean_squared_error: 0.6881 - val_mean_squared_error: 0.4735 - val_accuracy: 0.0000e+00 - 21s/epoch - 28ms/step
# Epoch 4/700
#
# Epoch 4: val_loss did not improve from 0.47206
# 778/778 - 20s - loss: 0.4689 - root_mean_squared_error: 0.6848 - mean_squared_error: 0.4689 - accuracy: 0.0000e+00 - val_loss: 0.4736 - val_root_mean_squared_error: 0.6882 - val_mean_squared_error: 0.4736 - val_accuracy: 0.0000e+00 - 20s/epoch - 26ms/step
# Epoch 5/700
#
# Epoch 5: val_loss did not improve from 0.47206
# 778/778 - 22s - loss: 0.4681 - root_mean_squared_error: 0.6842 - mean_squared_error: 0.4681 - accuracy: 0.0000e+00 - val_loss: 0.4753 - val_root_mean_squared_error: 0.6894 - val_mean_squared_error: 0.4753 - val_accuracy: 0.0000e+00 - 22s/epoch - 29ms/step
# Epoch 6/700
#
# Epoch 6: val_loss did not improve from 0.47206
# 778/778 - 23s - loss: 0.4677 - root_mean_squared_error: 0.6839 - mean_squared_error: 0.4677 - accuracy: 0.0000e+00 - val_loss: 0.4750 - val_root_mean_squared_error: 0.6892 - val_mean_squared_error: 0.4750 - val_accuracy: 0.0000e+00 - 23s/epoch - 30ms/step
# Epoch 7/700
#
# Epoch 7: val_loss did not improve from 0.47206
# 778/778 - 21s - loss: 0.4666 - root_mean_squared_error: 0.6830 - mean_squared_error: 0.4666 - accuracy: 0.0000e+00 - val_loss: 0.4751 - val_root_mean_squared_error: 0.6893 - val_mean_squared_error: 0.4751 - val_accuracy: 0.0000e+00 - 21s/epoch - 27ms/step
# Epoch 8/700
#
# Epoch 8: val_loss did not improve from 0.47206
# 778/778 - 20s - loss: 0.4661 - root_mean_squared_error: 0.6827 - mean_squared_error: 0.4661 - accuracy: 0.0000e+00 - val_loss: 0.4767 - val_root_mean_squared_error: 0.6904 - val_mean_squared_error: 0.4767 - val_accuracy: 0.0000e+00 - 20s/epoch - 26ms/step
# Epoch 9/700
#
# Epoch 9: val_loss did not improve from 0.47206
# 778/778 - 20s - loss: 0.4653 - root_mean_squared_error: 0.6821 - mean_squared_error: 0.4653 - accuracy: 0.0000e+00 - val_loss: 0.4770 - val_root_mean_squared_error: 0.6907 - val_mean_squared_error: 0.4770 - val_accuracy: 0.0000e+00 - 20s/epoch - 26ms/step
# Epoch 10/700
#
# Epoch 10: val_loss did not improve from 0.47206
# 778/778 - 21s - loss: 0.4646 - root_mean_squared_error: 0.6816 - mean_squared_error: 0.4646 - accuracy: 0.0000e+00 - val_loss: 0.4760 - val_root_mean_squared_error: 0.6899 - val_mean_squared_error: 0.4760 - val_accuracy: 0.0000e+00 - 21s/epoch - 27ms/step
# Epoch 11/700
#
# Epoch 11: val_loss did not improve from 0.47206
# 778/778 - 22s - loss: 0.4644 - root_mean_squared_error: 0.6814 - mean_squared_error: 0.4644 - accuracy: 0.0000e+00 - val_loss: 0.4769 - val_root_mean_squared_error: 0.6906 - val_mean_squared_error: 0.4769 - val_accuracy: 0.0000e+00 - 22s/epoch - 28ms/step
# Epoch 12/700
#
# Epoch 12: val_loss did not improve from 0.47206
# 778/778 - 23s - loss: 0.4647 - root_mean_squared_error: 0.6817 - mean_squared_error: 0.4647 - accuracy: 0.0000e+00 - val_loss: 0.4785 - val_root_mean_squared_error: 0.6917 - val_mean_squared_error: 0.4785 - val_accuracy: 0.0000e+00 - 23s/epoch - 29ms/step
# Epoch 12: early stopping

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
