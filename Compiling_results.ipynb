# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
cd drive/MyDrive
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive'
# /content/drive/MyDrive

# %%
cd BTP_Results/
# Out:
# /content/drive/My Drive/BTP_Results

# %%
n3 = np.loadtxt('model_report_n3_left')
n1 = np.loadtxt('evaluation_n1_left')
n2 = np.loadtxt('evaluation_n2_left')
n4 = np.loadtxt('evaluation_n4_left')
n5 = np.loadtxt('evaluation_n5_left')
n6 = np.loadtxt('evaluation_n6_left')
n7 = np.loadtxt('evaluation_n7_left')

# %%
n3
# Out:
# array([0.22692564, 0.45590943, 0.22692564])

# %%
x_values = np.arange(1,8,1)

# %%
y_values= []

# %%
y_values.append(n1[0])
y_values.append(n2[0])
y_values.append(n3[0])
y_values.append(n4[0])
y_values.append(n5[0])
y_values.append(n6[0])
y_values.append(n7[0])

# %%
plt.plot(x_values,y_values)
plt.xlabel('Person Number Nx')
plt.ylabel('Average MSE across R1,R2,R3 when Nx is unseen')
# Out:
# Text(0, 0.5, 'Average MSE across R1,R2,R3 when Nx is unseen')

# %%
from keras.models import Model
from keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Dropout
from keras.layers.core import Lambda
from keras.layers.core import Dense
from keras.layers import Flatten
from keras.layers import Input
import tensorflow as tf
import keras
import tensorflow
from keras import layers
import numpy as np
import tensorflow as tf
import tensorflow
from tensorflow import keras
from keras import layers
from tensorflow.keras.utils import plot_model
import pandas as pd
import matplotlib.pyplot as plt
from keras import regularizers, optimizers
from keras.layers import Dense, Dropout, Input
from keras.models import Sequential, load_model
from keras.callbacks import ModelCheckpoint
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError,MeanSquaredError,MeanAbsoluteError
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
import os

# %%
model = keras.models.load_model('best_model_n1_left.h5')

# %%
cd ..
# Out:
# /content/drive/MyDrive

# %%
x = np.load('x_new_n2.npy')
y = np.load('y_new_n2.npy')

# %%
x = np.load('complete_x.npy')
y = np.load('complete_y.npy')

# %%
# Out:
# 657/657 [==============================] - 7s 11ms/step - loss: 0.1475 - mean_absolute_error: 0.3210 - mean_squared_error: 0.1475
# 0.14748238027095795

# %%
print(model.evaluate(x[:3000],y[:3000])
# Out:
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0638 - mean_absolute_error: 0.2196 - mean_squared_error: 0.0638
# [0.0638110488653183, 0.21964406967163086, 0.0638110488653183]

# %%
x_loss = []
for i in range(7):
  x_loss.append((model.evaluate(x[3000*i:3000*(i+1)],y[3000*i:3000*(i+1)]))[0])
  print(model.evaluate(x[3000*i:3000*(i+1)],y[3000*i:3000*(i+1)]))
# Out:
# ...
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0638 - mean_absolute_error: 0.2196 - mean_squared_error: 0.0638
# [0.0638110488653183, 0.21964406967163086, 0.0638110488653183]
# ...
# 94/94 [==============================] - 1s 11ms/step - loss: 0.2771 - mean_absolute_error: 0.5244 - mean_squared_error: 0.2771
# [0.27709153294563293, 0.5244148969650269, 0.27709153294563293]
# ...
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0641 - mean_absolute_error: 0.1676 - mean_squared_error: 0.0641
# [0.0640745684504509, 0.1676332801580429, 0.0640745684504509]
# ...
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0855 - mean_absolute_error: 0.1819 - mean_squared_error: 0.0855
# [0.08545960485935211, 0.1819140613079071, 0.08545960485935211]
# ...
# 94/94 [==============================] - 1s 11ms/step - loss: 0.3304 - mean_absolute_error: 0.5629 - mean_squared_error: 0.3304
# [0.3304142355918884, 0.5628880262374878, 0.3304142355918884]
# ...

# %%
plt.plot(x_values,x_loss)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
preds = model.predict(x[:3000])

# %%
print('RMSE',mean_squared_error(y[:3000],preds,squared = False))
print('MSE',mean_squared_error(y[:3000],preds,squared = True))
print('MAE',mean_absolute_error(y[:3000],preds))
print('R2 Score',r2_score(y[:3000],preds))
# Out:
# RMSE 0.24713421819571815
# MSE 0.06381105661155982
# MAE 0.21964406398295486
# R2 Score -1.596310914021764e+26

# %%
mean_squared_error(y[0],preds[0])
# Out:
# 0.05455252290891339

# %%
res = 0
for i in range(len(preds[0])):
  res+=(y[0][i]-preds[0][i])**2

# %%
res = 0
for i in range(len(preds)):
  res+=r2_score(y[i+6000],preds[i])

# %%
res/len(preds)
# Out:
# 0.3935820047856079

# %%
preds = model.predict(x[3000:6000])

# %%
preds = model.predict(x[6000:9000])

# %%
res = 0
for i in range(len(preds)):
  res+=r2_score(y[i+6000],preds[i])
print(res/len(preds))
# Out:
# 0.6277356925372441

# %%
preds = model.predict(x[9000:12000])

# %%
res = 0
for i in range(len(preds)):
  res+=r2_score(y[i+9000],preds[i])
print(res/len(preds))
# Out:
# 0.6058688722600526

# %%
preds = model.predict(x[12000:15000])

# %%
res = 0
for i in range(len(preds)):
  res+=r2_score(y[i+12000],preds[i])
print(res/len(preds))
# Out:
# 0.3860397427190511

# %%
preds = model.predict(x[15000:18000])

# %%
res = 0
for i in range(len(preds)):
  res+=r2_score(y[i+15000],preds[i])
print(res/len(preds))
# Out:
# 0.9196808614671388

# %%
preds = model.predict(x[18000:])
res = 0
for i in range(len(preds)):
  res+=r2_score(y[i+18000],preds[i])
print(res/len(preds))
# Out:
# 0.49829587133264575

# %%
np.savetxt('model_eval_n1_left_n2_MSE_MAE.txt',model.evaluate(x,y))
